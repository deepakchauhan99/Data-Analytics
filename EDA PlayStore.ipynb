# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings ("ignore")

pd.set_option("display.max_columns", None)
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\chauh\\OneDrive\\Desktop\\Jupyter Notebook\\Test'

# %%
data=pd.read_csv(r"C:\Users\chauh\Downloads\New folder (2)\Google playstore4.csv")

# %%
data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10836       10836                                   Sya9a Maroc - FR
# 10837       10837                   Fr. Mike Schmitz Audio Teachings
# 10838       10838                             Parkinson Exercices FR
# 10839       10839                      The SCP Foundation DB fr nn5n
# 10840       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size in Bytes   9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data.drop((10472),inplace=True)

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce')
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data["Installs"].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
data['Installs'] = data['Installs'].str.replace(',','').str.replace('+','')

# %%
data["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
# 3   215644   25M  50000000  Free     0           Teen
# 4      967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
data["Size"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["Size"].loc[data["Size"].str.contains("M")].value_counts().sum()
# Out:
# np.int64(8829)

# %%
data["Size"].loc[data["Size"].str.contains("k")].value_counts().sum()
# Out:
# np.int64(316)

# %%
data["Size"].loc[data["Size"].str.contains("Varies with device")].value_counts().sum()
# Out:
# np.int64(1695)

# %%
def convert_size(Size):
    if isinstance (Size, str):
        if "k" in Size:
            return float(Size.replace("k",''))*1024
        elif "M" in Size:
            return float(Size.replace("M",''))*1024 * 1024
        elif "Varies with device" in Size: 
            return np.nan

    return Size

# %%
data["Size"] = data["Size"].apply(convert_size)

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size  Installs  Type Price Content Rating  \
# 0      159  19922944.0     10000  Free     0       Everyone
# 1      967  14680064.0    500000  Free     0       Everyone
# 2    87510   9122611.2   5000000  Free     0       Everyone
# 3   215644  26214400.0  50000000  Free     0           Teen
# 4      967   2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.rename(columns ={"Size": "Size in Bytes"}, inplace =True)

# %%
data["Size in Bytes"].unique()
# Out:
# array([1.99229440e+07, 1.46800640e+07, 9.12261120e+06, 2.62144000e+07,
#        2.93601280e+06, 5.87202560e+06, 3.04087040e+07, 3.46030080e+07,
#        3.25058560e+06, 2.93601280e+07, 1.25829120e+07, 2.09715200e+07,
#        2.20200960e+07, 3.87973120e+07, 2.83115520e+06, 5.76716800e+06,
#        1.78257920e+07, 4.08944640e+07, 3.25058560e+07, 4.40401920e+06,
#        7.34003200e+06, 2.41172480e+07, 6.29145600e+06, 6.39631360e+06,
#        4.82344960e+06, 9.64689920e+06, 5.45259520e+06, 1.15343360e+07,
#        2.51658240e+07,            nan, 9.85661440e+06, 1.57286400e+07,
#        1.04857600e+07, 1.25829120e+06, 2.72629760e+07, 8.38860800e+06,
#        8.28375040e+06, 5.87202560e+07, 5.97688320e+07, 3.67001600e+07,
#        5.66231040e+07, 2.05824000e+05, 3.77487360e+06, 5.97688320e+06,
#        9.01775360e+06, 2.51658240e+06, 2.83115520e+07, 2.62144000e+06,
#        1.67772160e+07, 3.56515840e+06, 9.33232640e+06, 4.08944640e+06,
# ...

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size in Bytes  Installs  Type Price Content Rating  \
# 0      159     19922944.0     10000  Free     0       Everyone
# 1      967     14680064.0    500000  Free     0       Everyone
# 2    87510      9122611.2   5000000  Free     0       Everyone
# 3   215644     26214400.0  50000000  Free     0           Teen
# 4      967      2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
data["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
data["Price"] = data["Price"].str.replace("$",'')

# %%
data["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size in Bytes  Installs  Type  Price Content Rating  \
# 0      159     19922944.0     10000  Free    0.0       Everyone
# 1      967     14680064.0    500000  Free    0.0       Everyone
# 2    87510      9122611.2   5000000  Free    0.0       Everyone
# 3   215644     26214400.0  50000000  Free    0.0           Teen
# 4      967      2936012.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
data["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
data["Current Ver"].loc[data["Current Ver"].str.contains("Varies with device", na=False)].value_counts().sum()
# Out:
# np.int64(1459)

# %%
data["Rating"].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
data["Rating"] = data["Rating"].fillna(data["Rating"].median())

# %%
data["Size in Bytes"] = data["Size in Bytes"].fillna(data["Size in Bytes"].median())

# %%
data["Type"] = data["Type"].fillna(data["Type"].mode())

# %%
data["Android Ver"] = data["Android Ver"].fillna(data["Android Ver"].mode())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size in Bytes   10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
data["Android Ver"].mode()
# Out:
# 0    4.1 and up
# Name: Android Ver, dtype: object

# %%
data["Android Ver"].isnull().sum()
# Out:
# np.int64(2)

# %%
data["Installs"] = pd.to_numeric(data["Installs"])

# %%
data.describe()
# Out:
#              Rating       Reviews  Size in Bytes      Installs         Price
# count  10840.000000  1.084000e+04   1.084000e+04  1.084000e+04  10840.000000
# mean       4.206476  4.441529e+05   2.116502e+07  1.546434e+07      1.027368
# std        0.480342  2.927761e+06   2.199610e+07  8.502936e+07     15.949703
# min        1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01   6.186598e+06  1.000000e+03      0.000000
# 50%        4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04   2.726298e+07  5.000000e+06      0.000000
# max        5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size in Bytes   10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# Current Ver       8
# Android Ver       2
# Type              1
# Category          0
# App               0
# Size in Bytes     0
# Reviews           0
# Rating            0
# Installs          0
# Content Rating    0
# Price             0
# Last Updated      0
# Genres            0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels = False, cbar = False, cmap = "viridis")
# Out:
# <Axes: >

# %%
missing_percentage = data.isnull().sum()/len(data)*100
missing_percentage.plot(kind="bar")
plt.xlabel("Columns")
plt.ylabel("Missing Percentage")
plt.title("Percentage of Missing values in each column")
plt.show()

# %%
missing_percentage[missing_percentage<1].plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['Rating'], bins=20, kde=True)
plt.title('Distribution of Ratings')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='Category', y='Rating', data=data)
plt.xticks(rotation=90)
plt.title('Ratings by Category')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Reviews', y='Rating', data=data)
plt.title('Ratings vs Reviews')
plt.xscale('log')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=data['Content Rating'].value_counts().index, y=data['Content Rating'].value_counts().values)
plt.title('Content Rating Distribution')
plt.show()

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size in Bytes  Installs  Type  Price Content Rating  \
# 0      159     19922944.0     10000  Free    0.0       Everyone
# 1      967     14680064.0    500000  Free    0.0       Everyone
# 2    87510      9122611.2   5000000  Free    0.0       Everyone
# 3   215644     26214400.0  50000000  Free    0.0           Teen
# 4      967      2936012.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data['Rating'].dropna(), kde=True, bins=20, color='skyblue')
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Apps')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, y='Category', order=data['Category'].value_counts().index[:10], palette='viridis')
plt.title('Top 10 App Categories')
plt.xlabel('Count')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=data, x='Type', y='Rating', palette='Set2')
plt.title('App Rating by Type (Free vs Paid)')
plt.xlabel('Type')
plt.ylabel('Rating')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='Installs', y='Rating', hue='Type', alpha=0.6)
plt.xscale('log')
plt.title('Rating vs Installs')
plt.xlabel('Installs (log scale)')
plt.ylabel('Rating')
plt.legend()
plt.tight_layout()
plt.show()
